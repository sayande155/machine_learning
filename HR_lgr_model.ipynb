# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("HR_comma_sep.csv")
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_monthly_hours  \
# 0                0.38             0.53               2                    157
# 1                0.80             0.86               5                    262
# 2                0.11             0.88               7                    272
# 3                0.72             0.87               5                    223
# 4                0.37             0.52               2                    159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_monthly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
plt.bar(df["salary"], df["left"], bottom=0.5)
# Out:
# <BarContainer object of 14999 artists>

# %%
left_1 = df[df["left"] == 1]
retained = df[df["left"] == 0]

# %%
print(left_1.shape)
print(retained.shape)
# Out:
# (3571, 10)
# (11428, 10)

# %%
df.groupby("left")[df.select_dtypes(include="number").columns].mean()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_monthly_hours  time_spend_company  Work_accident  left  \
# left
# 0                199.060203            3.380032       0.175009   0.0
# 1                207.419210            3.876505       0.047326   1.0
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %%
print(pd.crosstab(df.salary, df.left))
pd.crosstab(df.salary, df.left).plot(kind="bar")
# Out:
# left       0     1
# salary
# high    1155    82
# low     5144  2172
# medium  5129  1317
# <Axes: xlabel='salary'>

# %%
pd.crosstab(df['Department'], df['left']).plot(kind='bar')
pd.crosstab(df['Department'], df['left']).plot(kind='line')
# Out:
# <Axes: xlabel='Department'>
