# %% [markdown]
# # Dummy Variables

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## 1. Using pd.get_dummies()

# %%
df = pd.read_csv("home_prices_dummy.csv")
df
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %% [markdown]
# ### Categorical Variables
# 1. Nominal Variables : Variables who have no rankings in between of them
# 2. Ordinal Variables : Variables who have ranking in between them

# %%
dummy = pd.get_dummies(df.town, dtype=int)
dummy
# Out:
#     monroe township  robinsville  west windsor
# 0                 1            0             0
# 1                 1            0             0
# 2                 1            0             0
# 3                 1            0             0
# 4                 1            0             0
# 5                 0            0             1
# 6                 0            0             1
# 7                 0            0             1
# 8                 0            0             1
# 9                 0            1             0
# 10                0            1             0
# 11                0            1             0
# 12                0            1             0

# %%
merged = pd.concat([df, dummy], axis="columns")
merged
# Out:
#                town  area   price  monroe township  robinsville  west windsor
# 0   monroe township  2600  550000                1            0             0
# 1   monroe township  3000  565000                1            0             0
# 2   monroe township  3200  610000                1            0             0
# 3   monroe township  3600  680000                1            0             0
# 4   monroe township  4000  725000                1            0             0
# 5      west windsor  2600  585000                0            0             1
# 6      west windsor  2800  615000                0            0             1
# 7      west windsor  3300  650000                0            0             1
# 8      west windsor  3600  710000                0            0             1
# 9       robinsville  2600  575000                0            1             0
# 10      robinsville  2900  600000                0            1             0
# ...

# %%
final = merged.drop(['town', 'west windsor'], axis="columns")
final
# Out:
#     area   price  monroe township  robinsville
# 0   2600  550000                1            0
# 1   3000  565000                1            0
# 2   3200  610000                1            0
# 3   3600  680000                1            0
# 4   4000  725000                1            0
# 5   2600  585000                0            0
# 6   2800  615000                0            0
# 7   3300  650000                0            0
# 8   3600  710000                0            0
# 9   2600  575000                0            1
# 10  2900  600000                0            1
# 11  3100  620000                0            1
# 12  3600  695000                0            1

# %%
x = final.drop(['price'], axis='columns')
y = final.price

# %%
reg = LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.score(x,y) * 100
# Out:
# 95.73929037221873

# %%
reg.predict([[2800,1,0]])   # monroe township
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([565089.22812299])

# %%
reg.predict([[2800,0,1]])   # robinsville
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([590775.63964739])

# %%
reg.predict([[2800,0,0]])   # west windsor
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([605103.20361213])

# %%
reg.predict(x)
# Out:
# array([539709.7398409 , 590468.71640508, 615848.20468716, 666607.18125134,
#        717366.15781551, 579723.71533005, 605103.20361213, 668551.92431735,
#        706621.15674048, 565396.15136531, 603465.38378844, 628844.87207052,
#        692293.59277574])

# %%
reg.score(x,y)
# Out:
# 0.9573929037221873

# %%
reg.predict([[3400,0,0]])
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([681241.66845839])

# %% [markdown]
# ## 2. One Hot Encoder

# %% [markdown]
# ### Label Encoder

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()
dfle = df
dfle
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
dfle.town = le.fit_transform(dfle.town)

# %%
dfle
# Out:
#     town  area   price
# 0      0  2600  550000
# 1      0  3000  565000
# 2      0  3200  610000
# 3      0  3600  680000
# 4      0  4000  725000
# 5      2  2600  585000
# 6      2  2800  615000
# 7      2  3300  650000
# 8      2  3600  710000
# 9      1  2600  575000
# 10     1  2900  600000
# 11     1  3100  620000
# 12     1  3600  695000

# %%
x = df[['town', 'area']].values   # --> this .values will give 2d array not an dataframe
x
# Out:
# array([[   0, 2600],
#        [   0, 3000],
#        [   0, 3200],
#        [   0, 3600],
#        [   0, 4000],
#        [   2, 2600],
#        [   2, 2800],
#        [   2, 3300],
#        [   2, 3600],
#        [   1, 2600],
#        [   1, 2900],
#        [   1, 3100],
#        [   1, 3600]])

# %%
y = df['price']
y
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: price, dtype: int64

# %%
from sklearn.compose import ColumnTransformer
cl = ColumnTransformer([('town', preprocessing.OneHotEncoder(), [0])], remainder='passthrough')

# %%
x = cl.fit_transform(x)
x
# Out:
# array([[1.0e+00, 0.0e+00, 0.0e+00, 2.6e+03],
#        [1.0e+00, 0.0e+00, 0.0e+00, 3.0e+03],
#        [1.0e+00, 0.0e+00, 0.0e+00, 3.2e+03],
#        [1.0e+00, 0.0e+00, 0.0e+00, 3.6e+03],
#        [1.0e+00, 0.0e+00, 0.0e+00, 4.0e+03],
#        [0.0e+00, 0.0e+00, 1.0e+00, 2.6e+03],
#        [0.0e+00, 0.0e+00, 1.0e+00, 2.8e+03],
#        [0.0e+00, 0.0e+00, 1.0e+00, 3.3e+03],
#        [0.0e+00, 0.0e+00, 1.0e+00, 3.6e+03],
#        [0.0e+00, 1.0e+00, 0.0e+00, 2.6e+03],
#        [0.0e+00, 1.0e+00, 0.0e+00, 2.9e+03],
#        [0.0e+00, 1.0e+00, 0.0e+00, 3.1e+03],
#        [0.0e+00, 1.0e+00, 0.0e+00, 3.6e+03]])

# %%
x = x[:,1:]

# %%
reg.fit(x, y)
# Out:
# LinearRegression()

# %%
reg.predict(x)
# Out:
# array([539709.7398409 , 590468.71640508, 615848.20468716, 666607.18125134,
#        717366.15781552, 579723.71533004, 605103.20361213, 668551.92431735,
#        706621.15674048, 565396.1513653 , 603465.38378843, 628844.87207052,
#        692293.59277574])

# %%
reg.score(x,y)
# Out:
# 0.9573929037221873

# %%
reg.predict([[1,0,2800]]) # 2800 sqr ft home in robbinsville
# Out:
# array([590775.63964739])

# %% [markdown]
# ### Excercise

# %%
cars = pd.read_csv("car_dummy.csv")
cars
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)
# 0                  BMW X5    69000          18000         6
# 1                  BMW X5    35000          34000         3
# 2                  BMW X5    57000          26100         5
# 3                  BMW X5    22500          40000         2
# 4                  BMW X5    46000          31500         4
# 5                 Audi A5    59000          29400         5
# 6                 Audi A5    52000          32000         5
# 7                 Audi A5    72000          19300         6
# 8                 Audi A5    91000          12000         8
# 9   Mercedez Benz C class    67000          22000         6
# 10  Mercedez Benz C class    83000          20000         7
# 11  Mercedez Benz C class    79000          21000         7
# 12  Mercedez Benz C class    59000          33000         5

# %%
cars.columns
# Out:
# Index(['Car Model', 'Mileage', 'Sell Price($)', 'Age(yrs)'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
cars['Car Model'] = le.fit_transform(cars['Car Model'])

# %%
cars
# Out:
#     Car Model  Mileage  Sell Price($)  Age(yrs)
# 0           1    69000          18000         6
# 1           1    35000          34000         3
# 2           1    57000          26100         5
# 3           1    22500          40000         2
# 4           1    46000          31500         4
# 5           0    59000          29400         5
# 6           0    52000          32000         5
# 7           0    72000          19300         6
# 8           0    91000          12000         8
# 9           2    67000          22000         6
# 10          2    83000          20000         7
# 11          2    79000          21000         7
# 12          2    59000          33000         5

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer([('Car_Model_ohe', OneHotEncoder(), ["Car Model"])], remainder="passthrough")

# %%
x = cars[['Car Model', 'Mileage', 'Age(yrs)']]
y = cars['Sell Price($)']

# %%
x = ct.fit_transform(x)
x
# Out:
# array([[0.00e+00, 1.00e+00, 0.00e+00, 6.90e+04, 6.00e+00],
#        [0.00e+00, 1.00e+00, 0.00e+00, 3.50e+04, 3.00e+00],
#        [0.00e+00, 1.00e+00, 0.00e+00, 5.70e+04, 5.00e+00],
#        [0.00e+00, 1.00e+00, 0.00e+00, 2.25e+04, 2.00e+00],
#        [0.00e+00, 1.00e+00, 0.00e+00, 4.60e+04, 4.00e+00],
#        [1.00e+00, 0.00e+00, 0.00e+00, 5.90e+04, 5.00e+00],
#        [1.00e+00, 0.00e+00, 0.00e+00, 5.20e+04, 5.00e+00],
#        [1.00e+00, 0.00e+00, 0.00e+00, 7.20e+04, 6.00e+00],
#        [1.00e+00, 0.00e+00, 0.00e+00, 9.10e+04, 8.00e+00],
#        [0.00e+00, 0.00e+00, 1.00e+00, 6.70e+04, 6.00e+00],
#        [0.00e+00, 0.00e+00, 1.00e+00, 8.30e+04, 7.00e+00],
#        [0.00e+00, 0.00e+00, 1.00e+00, 7.90e+04, 7.00e+00],
#        [0.00e+00, 0.00e+00, 1.00e+00, 5.90e+04, 5.00e+00]])

# %%
x = x[:, 1:]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict([[0,1,45000,4]])
# Out:
# array([36991.31721062])

# %%
model.score(x,y)
# Out:
# 0.9417050937281082

# %%
# import pickle

# %%
# with open('car_dummy_model.pkl', 'wb') as f:
#     pickle.dump(model, f)

# %%
import joblib

# %%
joblib.dump(model, 'car_dummy_model.pkl')
# Out:
# ['car_dummy_model.pkl']

# %%
test_model = joblib.load('car_dummy_model.pkl')

# %%
test_model.score(x,y)
# Out:
# 0.9417050937281082
